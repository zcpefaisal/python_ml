# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.23.2'

# %%
pd.__version__
# Out:
# '1.4.3'

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# average price of BMW cars with rounding 3
df[df.Make == 'BMW'].MSRP.mean().round(3)
# Out:
# 61546.763

# %%
# subset of cars after year 2015
df[df.Year >= 2015]
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34     FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 41      BMW    2 Series  2016     premium unleaded (required)      240.0
# 42      BMW    2 Series  2016     premium unleaded (required)      240.0
# ...     ...         ...   ...                             ...        ...
# 11898   BMW          Z4  2015     premium unleaded (required)      300.0
# 11899   BMW          Z4  2015     premium unleaded (required)      335.0
# 11900   BMW          Z4  2016     premium unleaded (required)      300.0
# 11901   BMW          Z4  2016     premium unleaded (required)      240.0
# 11902   BMW          Z4  2016     premium unleaded (required)      335.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
# get all the column missing value count
df[df.Year >= 2015].isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              51
# Engine Cylinders        8
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         5
# Market Category      1324
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
# get only Engine HP column missing value count
df[df.Year >= 2015].isnull().sum()['Engine HP']
# Out:
# 51

# %%
# get only Engine HP column missing value count
df[df.Year >= 2015]['Engine HP'].isnull().sum()
# Out:
# 51

# %%
# Calculate the average "Engine HP" in the dataset.
mean_hp = df['Engine HP'].mean().round(2)
mean_hp
# Out:
# 249.39

# %%
df['Engine HP'].fillna(0).mean()
# Out:
# 247.94174920261878

# %%
df['Engine HP'].fillna(mean_hp).mean()
# Out:
# 249.3860928319624

# %%
df[df.Make == "Rolls-Royce"]
# Out:
#               Make                   Model  Year             Engine Fuel Type  \
# 2921   Rolls-Royce                Corniche  2001  premium unleaded (required)
# 3505   Rolls-Royce                    Dawn  2016  premium unleaded (required)
# 5275   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5276   Rolls-Royce         Ghost Series II  2015  premium unleaded (required)
# 5277   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5278   Rolls-Royce         Ghost Series II  2016  premium unleaded (required)
# 5279   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5280   Rolls-Royce                   Ghost  2012  premium unleaded (required)
# 5281   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5282   Rolls-Royce                   Ghost  2013  premium unleaded (required)
# 5283   Rolls-Royce                   Ghost  2014  premium unleaded (required)
# ...

# %%
# Select only columns "Engine HP", "Engine Cylinders", "highway MPG".
df[df.Make=='Rolls-Royce'][["Engine HP","Engine Cylinders","highway MPG"]]
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5276       563.0              12.0           21
# 5277       563.0              12.0           21
# 5278       563.0              12.0           21
# 5279       563.0              12.0           20
# 5280       563.0              12.0           20
# 5281       563.0              12.0           21
# 5282       563.0              12.0           21
# 5283       563.0              12.0           21
# 5284       563.0              12.0           21
# 7443       322.0              12.0           15
# 7444       322.0              12.0           15
# 7553       453.0              12.0           19
# 7554       453.0              12.0           19
# 7555       453.0              12.0           19
# 7556       453.0              12.0           19
# 7557       453.0              12.0           19
# ...

# %%
# Select only columns "Engine HP", "Engine Cylinders", "highway MPG". and get unique value (remove duplicates)
df[df.Make=='Rolls-Royce'][["Engine HP","Engine Cylinders","highway MPG"]].drop_duplicates()
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
# create new dataframe with then selected rolls-royce data
df_rr = df[df.Make=='Rolls-Royce'][["Engine HP","Engine Cylinders","highway MPG"]].drop_duplicates()
df_rr
# Out:
#        Engine HP  Engine Cylinders  highway MPG
# 2921       325.0               8.0           15
# 3505       563.0              12.0           19
# 5275       563.0              12.0           21
# 5279       563.0              12.0           20
# 7443       322.0              12.0           15
# 7553       453.0              12.0           19
# 11448      624.0              12.0           21

# %%
X = df_rr.values
X
# Out:
# array([[325.,   8.,  15.],
#        [563.,  12.,  19.],
#        [563.,  12.,  21.],
#        [563.,  12.,  20.],
#        [322.,  12.,  15.],
#        [453.,  12.,  19.],
#        [624.,  12.,  21.]])

# %%
# Compute matrix-matrix multiplication between the transpose of X and X.
X.T.dot(X)
# Out:
# array([[1.754801e+06, 3.965600e+04, 6.519600e+04],
#        [3.965600e+04, 9.280000e+02, 1.500000e+03],
#        [6.519600e+04, 1.500000e+03, 2.454000e+03]])

# %%
# To get the transpose, use X.T
X.dot(X.T)
# Out:
# array([[105914., 183356., 183386., 183371., 104971., 147606., 203211.],
#        [183356., 317474., 317512., 317493., 181715., 255544., 351855.],
#        [183386., 317512., 317554., 317533., 181745., 255582., 351897.],
#        [183371., 317493., 317533., 317513., 181730., 255563., 351876.],
#        [104971., 181715., 181745., 181730., 104053., 146295., 201387.],
#        [147606., 255544., 255582., 255563., 146295., 205714., 283215.],
#        [203211., 351855., 351897., 351876., 201387., 283215., 389961.]])
